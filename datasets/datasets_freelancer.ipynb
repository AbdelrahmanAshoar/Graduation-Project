# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast
df = pd.read_csv("dataset_10000.csv")
df['Skills'] = df['Skills'].apply(
    lambda x: x.split(', ') if pd.notna(x) else x)
df.head(5)
# Out:
#            Name             Job Title      Field  \
# 0   Clara Perry   Academic Researcher  Education
# 1   Skylar Ward          BI Developer       Data
# 2    Diana Bell         IP Specialist      Legal
# 3   Rory Torres         Growth Hacker  Marketing
# 4  Yusuf Carter  Social Media Manager  Marketing
#
#                                               Skills  Number of Reviews  \
# 0  [R, Research Methodology, Literature Review, A...                251
# 1  [DAX, Python, ETL, Looker, Data Warehousing, T...                204
# 2  [Westlaw, Due Diligence, Legal Research, Paten...                123
# 3       [A/B Testing, Python, SQL, Google Analytics]                198
# 4  [Brand Strategy, Analytics, Community Manageme...                181
#
#                                     Review Sample  Avg Star Rating  \
# 0        Highly skilled, proactive communication.             3.81
# 1          Great communicator, met all deadlines.             3.74
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 10000 non-null  object
#  1   Job Title            10000 non-null  object
#  2   Field                10000 non-null  object
#  3   Skills               10000 non-null  object
#  4   Number of Reviews    10000 non-null  int64
#  5   Review Sample        10000 non-null  object
#  6   Avg Star Rating      10000 non-null  float64
#  7   Total Earning ($)    10000 non-null  int64
#  8   Salary Per Hour ($)  10000 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 703.3+ KB

# %%
df2_explode = df.explode('Skills')
df2_explode['Skills'].value_counts().head(25).plot(kind='bar', colormap='PiYG', figsize=(20, 7))
# Out:
# <Axes: xlabel='Skills'>
